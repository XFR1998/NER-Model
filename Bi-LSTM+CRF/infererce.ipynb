# %%
import pandas as pd
import numpy as np
import random
import torch
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import SequentialSampler, DataLoader

# %%
data_path = '../dataset/test.csv'
df = pd.read_csv(data_path, delimiter="\t")
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2657 entries, 0 to 2656
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2657 non-null   object
# dtypes: object(1)
# memory usage: 20.9+ KB
#                                               text
# 0          比如片子一开始说到的暴雪娱乐的作品有……CS……。其实我看到这个时也喷饭了，这
# 1                               辽宁14家城商行开始执行央行房贷政策
# 2  而本场面对西布朗这样一支弱队，相信维冈不会放过这样的机会。目前，风扬数据下，由于平值从中阻隔，
# 3                          《辐射》设计师Anderson转投inXile
# 4   中信晒卡是一张个性十足的借记卡，中信银行网站为其提供了一个特色操作平台，客户通过简单的操作，

# %%
from config import parse_args

args = parse_args()
def setup_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
setup_seed(args.seed)


args.tag2idx = {'O':0, 'B-0':1, 'I-0':2}
args.idx2tag = {0: 'O', 1: 'B-0', 2:'I-0'}

# %%
args.word2idx = pd.read_pickle('./word2idx.pkl')
args.vocab_len = len(args.word2idx)

print('vocab_len: ', args.vocab_len)
# Out:
# vocab_len:  3040

# %%
test_data = [[list(i)] for i in df['text']]

# %%
# test_data

# %%
from data_helper import NER_Dataset
test_data_datsset = NER_Dataset(test_data, args, test_mode=True)
sampler = SequentialSampler(test_data_datsset)
dataloader = DataLoader(test_data_datsset,
                        batch_size=args.test_batch_size,
                        sampler=sampler)

# %%
if torch.cuda.is_available():
    args.device = 'cuda:0'
    print('使用：', args.device,' ing........')
from model import BiLSTM_CRF
model = BiLSTM_CRF(args)
path = f'./save_model/best_model.pth'
model.load_state_dict(torch.load(path, map_location='cpu'))
model.to(args.device)
# Out:
# 使用： cuda:0  ing........
# BiLSTM_CRF(
#   (embedding): Embedding(3040, 300, padding_idx=3039)
#   (rnn): LSTM(300, 300, batch_first=True, bidirectional=True)
#   (hidden2tag): Linear(in_features=600, out_features=3, bias=True)
#   (crf): CRF(num_tags=3)
# )

# %%
# 保存有所样本的预测结果
predict_tag = []

model = model.eval()
with torch.no_grad():
    for sample in tqdm(dataloader, 'val'):
        sentence_tensor = sample['sentence_tensor'].to(args.device)
        mask_tensor = sample['mask_tensor'].to(args.device)
        # label_tensor = sample['label_tensor'].to(configs.device)
        out = model(sentence_tensor=sentence_tensor,
                    label_tensor=None,
                    mask_tensor=mask_tensor)

        for l in out:
            temp = []
            for i in l:
                temp.append(args.idx2tag[i])
            predict_tag.append(temp)
# Out:
# val: 100%|██████████| 84/84 [00:04<00:00, 20.07it/s]

# %%
from ark_nlp.factory.utils.conlleval import get_entity_bio
def extract_entity(label, text):
    entity_labels = []
    for _type, _start_idx, _end_idx in get_entity_bio(label, id2label=None):
            entity_labels.append({
                'start_idx': _start_idx,
                'end_idx': _end_idx,
                'type': _type,
                'entity': text[_start_idx: _end_idx + 1]
            })
    entity_list = []
    for info in entity_labels:
        entity_list.append(info['entity'])
    return entity_list

# %%
extract_entity(label=predict_tag[0], text=df['text'][0])
# Out:
# ['暴雪娱乐']

# %%
tag_list = []
for idx, label in enumerate(predict_tag):
    tag_list.append(extract_entity(label=label, text=df['text'][idx]))

# %%
tag_list
# Out:
# [['暴雪娱乐'],
#  ['辽宁14家城商行'],
#  ['西布朗', '维冈'],
#  ['inXile'],
#  ['中信银行'],
#  ['欧冠', '联盟杯'],
#  ['星展银行香港分行'],
#  ['民生蓝筹混合型', '民生加银'],
#  ['北京澳际教育咨询有限公司', '澳新亚留学中心'],
#  ['老特拉福德', '切尔西', '曼联'],
#  [],
#  ['布莱克本'],
#  ['拉科', '马拉加'],
#  ['挪威', '荷兰'],
#  ['波特', '华纳兄弟公司'],
#  ['网龙', '网龙'],
#  ['StarsWar6Killer', '上海正大广场'],
#  [],
#  ['博洛尼亚'],
#  ['光大三家银行'],
#  ['西南证券办公室'],
#  ['欧足联'],
#  ['阿森纳', '基辅迪纳摩'],
#  ['波尔多小镇一期'],
#  ['科隆', 'IEM5世界总决赛'],
#  ['宜昌高新区港窑路25号南苑', '南都御景1号楼12楼4'],
#  ['楼兰', '罗布泊西北岸'],
#  ['苏格兰', '意大利'],
#  ['塞维利亚', '皇马', '马竞'],
#  ['切尔西', '意大利', '罗马'],
#  ['长安'],
#  ['辉煌云上', '辉煌集团'],
#  ['北三环马甸桥'],
#  ['摩根大', '亚太区', '子行'],
#  ['宝钢'],
#  ['意甲'],
#  ['长篇新行', '老三工作室'],
#  ['荷兰', 'nec尼美根'],
#  ['雷曼兄弟'],
#  ['英国伦敦', 'Seas公司'],
#  ['印尼', '奥地利'],
#  ['纽卡斯尔', '热刺'],
#  ['质监局', '旧换新工作小组'],
#  ['南昌市兴业银行'],
#  ['华夏'],
#  ['梅塔利斯特'],
#  ['意甲', '联盟杯'],
#  ['民生银行'],
#  ['万江街道', '益电子厂现货'],
#  ['曜越太阳神'],
#  ['那不勒斯', '卡利亚里'],
#  ['德国复兴信贷银行', '美国国际集团（aig）'],
#  ['中国航天科技集团'],
#  [],
#  ['ac米兰', '拉齐奥'],
#  ['曼城', '英超'],
#  ['imf'],
#  ['吉隆滩'],
#  ['昆明市', '昆明市'],
#  ['太阳神', '橘子熊'],
#  ['伊朗革命卫队', '波斯湾', '霍尔木兹海'],
#  ['俄德', '芬兰'],
#  ['广发行', '广发行'],
#  ['中国国际数码互动娱', '上海国际博览中心'],
#  ['波鸿', '赫塔', '沃尔夫', '斯图加'],
#  ['BBFC'],
#  ['国际企业文化公园', '高尔夫球场'],
#  ['努曼西亚', '西班牙人', '马德里竞技', '拉科'],
#  ['兴业银行'],
#  ['河南省网络文化协会', '郑州市文化市场管理办公室科长袁德顺', '郑州市网吧行业协会'],
#  ['国际大厦8层新浪乐居嘉聊室'],
#  ['乌迪内斯', '莫斯科斯巴达克', '乌迪内斯'],
#  ['莱切', '莱切', '罗马'],
#  ['清华大学'],
#  ['台彩'],
#  ['事发大楼', '人保财险', '人保财险'],
#  ['深发展'],
#  ['山ECL场'],
#  ['香港'],
#  ['法新社', '远东地区'],
#  ['香港', '维多利亚港', '维多利亚港旁'],
#  ['里昂', '巴黎', '佛罗伦'],
#  ['华润置地（企业专区'],
#  ['南京', '江苏省苏州', '常州'],
#  ['卡利亚里', '森普多利亚'],
#  ['波兰', '纽约', '波兰'],
#  ['工行', '工行'],
#  ['沙尔克04', '曼城'],
#  ['切尔西', '英超', '斯坦福桥球场'],
#  ['民生银行'],
#  ['英超'],
#  ['意甲'],
#  ['英国国家美术馆科学'],
#  ['津滨大道南侧', '中环线2'],
#  ['那不勒斯', '热那亚'],
#  ['物业地', '9号楼1单元13楼166号'],
#  ['北京保利', '俏江南'],
#  ['云集超市'],
#  ['保加利亚'],
#  ['学校', '学生公寓', '教委'],
#  ['川迪'],
#  ['北京展览馆', '动物园', '中关村'],
#  ['尤文', '威廉希尔'],
#  ['每经', '上海', '北京', '深圳', '成都'],
#  ['拉科鲁尼亚队', '马拉加队'],
#  ['锡耶纳', '都灵'],
#  ['台湾'],
#  ['乌迪内', '意甲', '联盟杯'],
#  ['泸州', '中海地产'],
#  ['布里斯班', '三大沙岛摩顿岛'],
#  ['索马里海域', '联合国安理会'],
#  ['威尼斯'],
#  ['足彩', '米兰', '罗马'],
#  [],
#  ['桑坦德'],
#  [],
#  ['ief', '河南省郑州市七彩商都网吧顺利'],
#  ['新加坡'],
#  ['上海光大会展中心'],
#  ['西山林语'],
#  ['上海'],
#  ['罗马', '笑傲德比战紫'],
#  ['马来西亚'],
#  ['奥兰', '鳄鱼岛'],
#  ['威尼斯'],
#  ['IV'],
#  ['沙尔克', '阿森纳'],
#  ['宝钢集团'],
#  [],
#  ['星展银行私人银行'],
#  ['热刺'],
#  ['交通银行'],
#  ['Valve'],
#  ['bac', 'bac', '美国政府'],
#  ['切沃', '罗马'],
#  ['韩国', '中国'],
#  ['招商银行', '平安银行'],
#  ['中国人民银行'],
#  ['英超'],
#  ['西岗村'],
#  ['美国', '加拿大地区'],
#  ['中国外汇交易中心'],
#  ['伦敦', '富勒姆', '西汉姆'],
#  ['凯尔特人', '欧冠'],
#  ['斯图加特'],
#  ['招商银行', '工商银行'],
#  ['广州市林和西路广州体育学院东门体育馆'],
#  ['新华网', '喀布尔'],
#  ['福彩中心'],
#  ['金融街', '金融街'],
#  ['联赛', '赫尔城'],
#  ['阿尔及利亚', '哈利勒'],
#  ['绿城集团', '绿城集团'],
#  ['嘉陵江', '渝中半岛'],
#  ['切沃'],
#  ['育碧公司'],
#  ['中国政法大学'],
#  ['保险行业协会'],
#  ['邮储银行', '邮储银行江西省分行'],
#  ['东亚银行'],
#  ['拜仁', '佛罗伦'],
#  ['渣打银行'],
#  ['拜仁'],
#  ['皇马'],
#  ['公司业务部', '香港中银投资公司战略投资部', '中国信托业协会'],
#  ['工体西路', '日本'],
#  ['丰台区建委'],
#  ['挪威', '挪威'],
#  ['曼城'],
#  ['interwetten', '热刺'],
#  ['拉齐奥'],
#  ['希洪'],
#  ['北大法学院'],
#  ['区信访办'],
#  ['CrypticStudios'],
#  ['阿森纳'],
#  ['香港', '骄阳', '东方电影'],
#  ['赫尔城'],
#  ['桑坦德竞技', '西班牙人'],
#  ['yahoo'],
#  ['马里布'],
#  ['凯尔特人', '国米'],
#  ['美国政府'],
#  ['曼城', '曼城', '巴黎圣日耳曼'],
#  ['罗马', '切尔西', '罗马', '罗马'],
#  ['维冈'],
#  ['阿尔梅利亚', '奥萨苏纳'],
#  ['北京朝阳区某炒汇公司'],
#  ['加拉塔萨雷'],
#  ['广州市', '三行', '新中国大厦楼', '工行'],
#  [],
#  ['联盟杯'],
#  ['农业银行', '建设银行'],
#  ['上海'],
#  ['好莱坞'],
#  ['尼美根'],
#  ['西哈努克'],
#  ['澳彩', '拉齐奥'],
#  ['EA公司'],
#  ['银狐'],
#  ['博洛尼'],
#  ['沙尔克', '切尔西'],
#  ['汉堡', '斯图加特', '欧冠', '联盟杯'],
#  ['华贸中心', '东长安街', '华贸城'],
#  ['新浪乐居', '乐居电商', '功组织'],
#  ['cbd东', '通州'],
#  ['阿森纳', '阿森纳'],
#  ['央行上海总部'],
#  ['登青城山', '成都'],
#  ['瓦伦西浅', '米兰'],
#  [],
#  ['尼美根', '莫斯科斯巴达'],
#  ['泗水县', '泗水县'],
#  ['佳士得', '纽约'],
#  ['欧冠'],
#  ['英超'],
#  ['奥斯泰华'],
#  ['广发行', '广发行'],
#  ['里昂', '里昂'],
#  ['快钱公司'],
#  ['Midway'],
#  ['那不勒斯', '立博'],
#  ['欧冠'],
#  ['中房协'],
#  ['威廉', 'ssp'],
#  ['深圳平安银行'],
#  ['京西商务区', '丽泽商务区', '丽泽商务区'],
#  ['光大银行深圳分行信用卡中心'],
#  ['行业协会'],
#  ['上海', '无锡', 'CEC国际电子竞技冠军杯'],
#  ['标准列日', '桑普多利亚'],
#  ['伟德', 'bet365'],
#  ['北京'],
#  ['北京住房公积金管理中心', '北京市'],
#  ['中国'],
#  ['布莱克本', '利物浦'],
#  ['阿森纳', '基辅'],
#  ['热那亚'],
#  ['育碧'],
#  ['东京'],
#  ['LGD', 'G联赛'],
#  ['丽泽'],
#  [],
#  ['奥斯卡战线', '威尼斯电影节', '罗马电影节'],
#  ['英超', '富勒姆', '德比郡', 'interwetten'],
#  ['埃伍德公园球场'],
#  ['法国驻华大使馆语', '学术评'],
#  ['英国伦敦', 'Seas公司'],
#  ['印度空间组织', '中央政府'],
#  ['杭州市建设工程质监总站', '杭州市'],
#  ['朝阳区定福庄'],
#  ['国有银行', '交通银行'],
#  ['宝华工贸中心'],
#  ['中信新城', '亦庄核心生活区西侧', '亦庄'],
#  ['农行', '交行'],
#  ['深发展信用卡中心'],
#  ['wcg', '北京大学百年讲堂'],
#  ['卡尔斯', '赫尔城', '纽卡斯'],
#  ['美国证券交易委员会'],
#  ['橘子熊'],
#  ['热那亚'],
#  ['光大银行长春分行'],
#  ['新浪乐居'],
#  ['米二居', '东南五环光机电产业基地'],
#  ['皇家邮政行', '莫亚格林（moyagreene'],
#  ['网元网'],
#  ['波兰'],
#  ['北京', '长安福特'],
#  ['邮储'],
#  ['accumulator', '香港证监会', '金管局'],
#  ['花旗集团'],
#  ['castle', '渣打银行'],
#  ['人居环境委员会中华环境保护基金会'],
#  ['花旗', '类港股'],
#  ['宁波银行', '中国银行', '招商银行', '广发银行', '浦发银行', '交通银行'],
#  ['韩国星际争霸1'],
#  ['ParadoxInteractive今日'],
#  ['丽泽商务区'],
#  ['加拉塔', '本菲卡'],
#  ['中国人民银行'],
#  ['赫尔城', '维冈'],
#  ['德甲'],
#  ['加拉塔萨雷'],
#  ['泽尼特', '尤文图斯'],
#  ['KR', '华义SPIDER'],
#  ['拉科', '马德里', '毕尔巴鄂', '奥萨苏纳'],
#  ['石家庄六', 'G联赛'],
#  ['桑坦德竞技队', '毕尔巴鄂竞技队', '西甲'],
#  ['招商银行', '兴业银行', '中信银行'],
#  ['建设银行'],
#  ['农村信用社'],
#  ['证监会', '意达'],
#  ['上海国家会计学院'],
#  ['西泠印社秋季拍卖会', '杭州'],
#  ['联盟杯', '奥林匹亚科斯', '本菲卡', '加拉塔萨雷'],
#  ['意甲'],
#  ['子君村'],
#  ['西部拉贾斯坦邦上空'],
#  [],
#  ['亚庇东南海域'],
#  ['暴雪', '美国'],
#  ['尼美根', '荷甲', '华伦丹'],
#  ['尤文', '马拉加'],
#  ['“光耀东方广场'],
#  ['石镇交通上桥头林镇大朗镇清溪镇归位镇环常北路/环常西尾号8'],
#  ['广州'],
#  ['博彩公司', '罗马'],
#  ['罗马'],
#  ['中乡建', '群众'],
#  [],
#  ['miss', '凯恩斯市外南部'],
#  ['北京站', '中国电子大厦'],
#  [],
#  ['建行', '招行'],
#  ['吉林长春连邦长春市', '工农大路1128号欧亚7214室'],
#  ['西布朗'],
#  ['建行佛山分行'],
#  ['建行'],
#  ['纽卡斯尔队', '斯托克城队', '英超联赛'],
#  ['崇礼县'],
#  ['Westwood公司'],
#  ['台湾松岗科技'],
#  ['北邙山', '北邙山'],
#  ['G联赛'],
#  [],
#  ['联盟杯'],
#  ['尼美根队', '托特纳姆队'],
#  ['米德尔斯堡'],
#  ['联盟杯'],
#  ['英超', '意西足彩'],
#  ['拉科', '毕尔巴鄂', '奥萨苏纳'],
#  ['工商银行'],
#  ['海淀'],
#  ['曼彻斯特', '曼联'],
#  ['青山碧苑'],
#  ['中国银行', '招商银行', '交通银行'],
#  ['招行'],
#  ['北京家具协会'],
#  ['中国银行'],
#  ['乌迪内斯'],
#  ['美国任命', '美国空军'],
#  ['乐成中心b座21层'],
#  ['涿州市政广场南侧', '平安北街与华阳路交叉处向东'],
#  ['孟买', '印度', '海军'],
#  ['CCM'],
#  ['汇丰'],
#  ['济南'],
#  ['银联商务湖北分公司', '银联'],
#  ['visa'],
#  ['北京大观园'],
#  ['海洋'],
#  ['北京楼市', '百子湾', '朝阳公园', '中关村'],
#  ['日本橡胶贸易协会'],
#  ['中信嘉华银行'],
#  ['巴塞罗那市中心'],
#  ['老挝家具协会', '维沙蓬'],
#  ['博宝艺术网', '博宝艺术网'],
#  ['北京市朝阳区东三环南路23号国家体彩中心一层足彩征文组委会'],
#  ['Take-Two', 'FTC达'],
#  ['WCG', '湖北卫视'],
#  ['WCG'],
#  ['法兰克福队', '波鸿队'],
#  ['维拉', '阿森纳', '曼联', '宿命'],
#  ['切沃', '锡耶纳'],
#  ['农村信用社'],
#  ['中金公司', 'cpi'],
#  [],
#  ['新浪乐居'],
#  ['新华网', '深圳', '深圳发展银行'],
#  ['俄罗斯方块超人'],
#  ['海淀区知春路', 'Falcom'],
#  ['匡时', '西泠印社'],
#  ['招商银行', '北京银行', '浦发银行', '民生银行', '光大', '华夏'],
#  ['世嘉'],
#  ['人民银行'],
#  ['桑普多', '卡塔尼'],
#  ['埃弗顿', '西汉姆'],
#  ['PLU娱乐传媒'],
#  ['NirvanaDota战队'],
#  ['新体育中心路b'],
#  [],
#  ['平安银行'],
#  ['宏村', '典路线南湖南湖书院承志堂'],
#  ['日尔曼', '威廉'],
#  ['某国有银行广州分行'],
#  ['沈阳市"辽宁工业展览馆"', '广大电', '中国（沈阳）'],
#  ['深发展'],
#  ['江城', '东亚银行'],
#  ['中行'],
#  ['俄罗斯南部'],
#  ['澳际出国留学澳新亚留学中心'],
#  [],
#  ['ac米兰', '雷吉纳'],
#  ['CCM', 'PanDa战队'],
#  ['博彩公司'],
#  ['潇湘银行', '五行'],
#  ['宝钢'],
#  ['荷银', '中国北京', '上海', '深圳', '成都'],
#  ['安监局', '建设厅', '质监局', '人力保障厅', '建协'],
#  ['eswc'],
#  ['英冠', '博彩公司', '赫尔城'],
#  ['美国商界5'],
#  ['中房协'],
#  ['欧佩克'],
#  ['工商银行'],
#  ['英超'],
#  ['卡利亚里'],
#  ['红军', '勒沃', '枪手', '米堡'],
#  ['广发行'],
#  ['新疆', '四川地震灾区', '子教师（中小学'],
#  ['北京保利拍卖公司'],
#  ['博彩公司', 'ac米兰'],
#  ['oGs战队'],
#  ['ws包英雄', '联盟', '马工作室'],
#  ['北京'],
#  ['香港'],
#  ['THQ', 'BigHugeGames工作室'],
#  ['孟买', '印度中央机械工程研究所'],
#  ['贝蒂斯', '瓦伦'],
#  ['欧洲杯'],
#  ['中华全国集邮联合会', '山东省集邮协会'],
#  ['邮储北分'],
#  ['门兴', '勒沃库森'],
#  ['拉科', '西甲', '费耶诺德', '荷甲', 'interwetten'],
#  ['幸福谷happyvalley'],
#  ['切沃', '罗马'],
#  ['维冈'],
#  [],
#  ['工行', '电子银行'],
#  ['德州扑克'],
#  ['拜仁慕尼黑'],
#  ['燕郊区域'],
#  ['拉科鲁', '毕尔巴', '费耶诺德'],
#  ['香港'],
#  ['湖南省金融办', '湖南省'],
#  ['Convention'],
#  ['世博会', '伦敦', '伦敦的水晶宫'],
#  ['省联社'],
#  ['夏威夷水岸1号'],
#  ['博尔顿'],
#  ['翡翠收藏俱乐部'],
#  ['ac米兰'],
#  ['法国'],
#  ['香港'],
#  ['中国银行', '湖南信托'],
#  ['沙尔克', '险沃尔夫'],
#  ['大陆地区金融机构', '中国银联公司', '银联'],
#  ['沙荷路'],
#  [],
#  ['美国波音公司'],
#  ['马拉加'],
#  ['斯托克'],
#  ['罗森博格队', '瓦伦西亚队'],
#  ['黄山大门', '南大门'],
#  ['大宇公司', '北京软星'],
#  ['桑德兰'],
#  ['欧冠', '莫斯科斯巴达克', '费内巴切', '波尔图'],
#  ['南连金融街', '中关村', '金融街'],
#  ['江苏电视台'],
#  ['越南', '俄罗斯', '乌拉尔山脉'],
#  ['洛杉矶'],
#  ['美国', '纽约'],
#  ['澳彩'],
#  ['紫百合'],
#  ['北京华太'],
#  ['橘子熊', 'Gino'],
#  [],
#  ['热刺'],
#  ['宣明典居卖场'],
#  ['米兰', '恩波利', '罗马'],
#  ['清华大学建筑学院'],
#  ['曼联'],
#  [],
#  ['银联'],
#  ['足彩'],
#  ['Grubby', 'EG战队'],
#  ['罗马', '利物浦'],
#  ['山西省银行业协会'],
#  ['立博'],
#  ['建行', '建行', '房安居'],
#  ['法国国家队'],
#  ['好莱坞商会', '星光大道'],
#  [],
#  ['中国投洽会', '天津', '北京'],
#  ['工行'],
#  ['交通银行'],
#  ['尤文', '马拉加'],
#  ['曼联', '阿森纳', '勒沃沙尔克'],
#  ['希洪', '贝蒂斯'],
#  ['曼城', '沙尔克'],
#  ['工艺行业协会'],
#  ['厄普顿公园球场'],
#  [],
#  ['香港旅游局'],
#  ['西山'],
#  ['维旺迪集团', '维旺迪'],
#  ['嘉泰'],
#  ['招行武汉分行'],
#  ['马尔代夫', '香格里拉岛', '香格里拉酒店集团'],
#  ['荷兰', '冰岛'],
#  ['桑普', '联盟杯', '卡塔尼亚'],
#  ['那不勒斯'],
#  ['英超', '斯托克城'],
#  ['切沃', '博尔顿'],
#  ['福克斯公司'],
#  ['中国人民大学行政管理学研究所'],
#  ['游港杯', '浙江缔顺科技有限公司游戏港口团队'],
#  ['昌乐路文化市场'],
#  ['索尼'],
#  ['太平洋中心'],
#  ['金融街', '三里河', '丽泽商务区'],
#  ['法新社', '婆罗洲'],
#  [],
#  ['北京'],
#  ['中信银行'],
#  ['阿森纳', '欧冠'],
#  ['北京南区', '金融街'],
#  ['华谊兄弟'],
#  ['斯图加特'],
#  ['门兴', 'bet365', '澳彩'],
#  ['纽卡'],
#  ['切尔西', '曼城'],
#  ['EA'],
#  ['农商行'],
#  ['中国银行（601988.sh）', '工商银行（601398.sh）'],
#  ['金融街'],
#  ['福彩'],
#  ['马略卡', '维尔瓦'],
#  ['新浪乐居', '辉煌国际高尔夫球俱乐部'],
#  ['c罗', '维拉公园'],
#  ['供销社', '农业合作社', '农村信用社'],
#  ['帕纳辛奈科斯', '联盟杯'],
#  ['香港分行', '香港'],
#  ['韩亚银行', '韩国友利银行（中国）有限公司'],
#  ['乐园'],
#  ['北京', '海渔广场'],
#  ['桑普蓝鹰', '罗马'],
#  ['西甲', '努曼西', '维拉利'],
#  ['金象大药房', '我爱我家'],
#  ['招行信用卡中心'],
#  [],
#  ['纽卡斯', '赫尔城'],
#  ['乌迪内斯', '拉齐奥', '罗马'],
#  ['北京', '北京'],
#  ['英超'],
#  ['洛杉矶会展中心'],
#  ['兴业银行', 'cpi'],
#  [],
#  ['上海国家会计学院'],
#  ['乌迪', '切沃'],
#  ['中国电子竞技运动发展中心'],
#  ['桑德兰'],
#  ['洛杉矶国际会议中心'],
#  ['都灵'],
#  ['四川', '敦煌'],
#  ['北京娱乐通', '游戏天堂'],
#  ['仓储物流协会'],
#  ['成都泰', '泰律师事务所'],
#  ['曼城', '阿森纳'],
#  ['卡尔斯鲁厄队', '云达不来梅队', '德甲'],
#  ['利物浦', '西汉姆'],
#  ['农行', '暴眼中心', '农行'],
#  ['ac米兰'],
#  ['招行'],
#  ['重庆国际信托'],
#  ['东南亚众多海岛'],
#  ['米德尔', '威廉希尔'],
#  ['青玉螭龙钮', '台湾'],
#  ['THQ', 'TalesofValor”'],
#  ['rbs', '中国'],
#  ['魁北克彩票机构'],
#  ['丰台区区委办公室'],
#  ['都灵'],
#  ['联盟杯'],
#  ['北京'],
#  ['长江二桥道路'],
#  ['富勒姆', '英超', '维拉'],
#  ['欧战斯巴达人', '基辅迪纳摩', '欧冠', '奥斯特拉华'],
#  ['荣田路', '大工业区中心区', '临惠路'],
#  ['彩票监管部门'],
#  ['中信银行深圳分行信用卡中心', '人民银行深圳分行'],
#  ['G联赛'],
#  ['北京各商业银行', '北京', '央行'],
#  ['深发展'],
#  ['西班牙人队', '皇马'],
#  ['中国珠宝玉石首饰行业协会'],
#  ['汉雅轩'],
#  ['青城山'],
#  ['沙尔克04队', '柏林赫塔队', '德甲'],
#  ['伦敦', '博尔顿'],
#  ['桑德兰'],
#  ['洞爷', '南巴士运营', 'iburi号'],
#  ['威廉希尔'],
#  [],
#  ['安徽省皖农贸易有限公司业务部'],
#  ['新闸路石门路'],
#  ['西甲', '巴萨', '皇马'],
#  ['北京'],
#  ['顺义', '草公司院'],
#  ['丽泽金融商务区'],
#  [],
#  ['门兴', '科特布斯', '勒沃', '拜仁'],
#  ['林达海渔广场'],
#  ['招行'],
#  ['联盟杯'],
#  ['费内巴', '波尔图'],
#  ['农行', '杭州'],
#  ['布莱克本队', '利物浦队'],
#  ['merchantsbank'],
#  [],
#  [],
#  ['巴西'],
#  ['韩建地产', '旗下金贸中心'],
#  ['红海', '特洛'],
#  ['里湖北蕲春县', '北京', '杭州', '上海', '广州'],
#  ['雷吉纳', '紫百合'],
#  ['新浪乐居', '辉煌国际高尔夫球俱乐部'],
#  ['深发展信用卡中心'],
#  ['wcg'],
#  ['南美洲', '西西比河'],
#  ['合生世界村', '马驹桥镇', '金桥科技产业基地', '马驹桥'],
#  ['渣打'],
#  ['中国农业银行', '银联'],
#  ['纽卡', '俱乐部'],
#  ['波尔多', '切尔西'],
#  ['重庆市渝中区建委开发办'],
#  ['莱切'],
#  ['中国运载火箭技术研究院'],
#  ['意大利'],
#  ['复旦大学金融学院'],
#  ['保加利亚', '保加利亚'],
#  ['博彩公司', '布莱克'],
#  ['皇马'],
#  [],
#  ['新浪'],
#  ['喀山鲁宾', '莫陆军'],
#  ['北京市丰台区京荟广场文化产业园B座2层'],
#  ['澳际教育集团英国留学中心'],
#  ['加利福尼亚州阿纳海姆', '阿纳海姆会议中心'],
#  ['巴斯克人'],
#  ['西藏自治区拉萨市城关区拉萨市城关区雅美生态花园门口小卖部千禧旁边'],
#  ['上海国家会计学院'],
#  ['伯恩利'],
#  ['皇马', '令拉涅利'],
#  ['博尔顿'],
#  ['设计者村上隆所'],
#  ['桑德兰'],
#  ['尤文', '索夫'],
#  ['皇家邮政'],
#  ['莱切', '罗马'],
#  ['美国弗吉尼亚大学建筑系'],
#  ['拉科鲁尼亚队'],
#  ['银联', '广州'],
#  ['纽卡斯尔队', '斯托克城队', '英超联赛'],
#  ['富勒姆'],
#  ['钢铁人', 'KR'],
#  [],
#  ['博联网络', '天马店', '曙光中路248号', '曙光大邸二楼'],
#  ['中国银联'],
#  ['深发展'],
#  ['易居房地产研究院'],
#  ['巴勒莫', '雷吉纳'],
#  ['西河沿甲215号'],
#  ['交行'],
#  ['索维娅国际艺术村'],
#  ['美国在台协会', '布鲁京斯研究所东北亚政策'],
#  ['维冈'],
#  ['奇才', '麦迪逊广场花园', '尼克斯'],
#  ['乌迪内斯', '切沃'],
#  ['宁波市政府', '宁波金融ic卡试点'],
#  ['博洛尼', '立博', '意甲'],
#  ['中华人民共和国新闻出版总署科技与数字出版司'],
#  ['贝尔格莱德游击', '标准列日'],
#  ['DragonForce'],
#  ['辽宁大连智星大连市沙河口区长兴电子城3楼E区'],
#  ['暴雪', '九城', '暴雪'],
#  ['桑普多利亚', '标准列日'],
#  [],
#  ['俄罗斯'],
#  ['EidosInteractive'],
#  ['莫斯科中央陆军', '联盟杯'],
#  ['中钢协'],
#  ['深圳', '光大'],
#  ['曼联'],
#  [],
#  ['银行业监督管理委员会', '美国'],
#  ['多特蒙德'],
#  ['武昌区徐东花市', '武青'],
#  ['香港', '招商银行', '华夏银行', '香港'],
#  ['KeSPA', '暴雪', 'GomTV'],
#  ['英超', '威廉'],
#  ['英超'],
#  ['贝蒂斯', '瓦伦'],
#  ['台湾'],
#  ['莱切'],
#  ['雷吉纳队', '博洛尼亚队', '意甲'],
#  ['王府井新华书店'],
#  ['英国必发公司', '都灵'],
#  ['欧冠', '曼城'],
#  ['Moon', 'GSL'],
#  ['南师大', '江苏省文联党组'],
#  ['工行北京', '上海地区的客服'],
#  ['韩亚银行', '中国', '山东'],
#  [],
#  ['dtalipapa市'],
#  ['EA'],
#  ['北京大学法学院'],
#  ['日本', '中国旅行'],
#  ['米堡'],
#  ['布莱克本'],
#  ['中国保险学会', '保险经理人'],
#  ['重庆银行'],
#  ['潜店ticabodivingcentre'],
#  ['刀锋工作室', '莫斯科斯巴达'],
#  ['赫特潟湖', '澳大利亚', '科宁公司', 'cogniscompany'],
#  ['银联', '广州易联商业服务有限公司', '“易联公司'],
#  ['北京'],
#  ['台公安分局', '北京', '北京'],
#  ['伟业顾问', '华远', '九都汇'],
#  ['莱切'],
#  ['盖蒂基金会'],
#  ['盖蒂博物馆', '盖蒂研究所', '盖蒂基金会', '盖蒂信托'],
#  ['华润'],
#  ['阿尔梅'],
#  ['西汉姆', '博彩公司'],
#  ['热刺'],
#  ['广发行'],
#  ['北京'],
#  ['中国集邮总公司'],
#  ['Relic'],
#  ['星展银行'],
#  ['东亚银行'],
#  ['CPL'],
#  ['荷甲', '荷甲', '沙尔克04'],
#  ['葡萄牙人奎罗斯', '曼联'],
#  ['美国雇佣军', '古巴'],
#  ['山西代县'],
#  ['益海嘉里'],
#  ['上海黄金交易所'],
#  ['北京消防局', '央视'],
#  ['渣打', '印度工程公司'],
#  ['联赛', '沙尔克', '德甲'],
#  ['拉齐奥'],
#  ['GameSpot'],
#  ['建行'],
#  ['中信银行', '南京银行', '兴业银行', '深发展'],
#  ['北京', '中国华夏易经研究会', '中国姓名文化研究会'],
#  ['银行业协会'],
#  ['官方组委会', 'G联赛'],
#  ['sport'],
#  ['纽卡', '切尔西'],
#  ['联盟杯'],
#  ['曜越太阳神'],
#  ['尼罗河流淌', '西岸大墓'],
#  ['塔内加航天空军基地'],
#  ['暴雪嘉年华', '美国加州阿纳海姆会议中心'],
#  ['湖州', '美泉宫'],
#  ['招行'],
#  ['阿森纳', '维冈'],
#  ['桑坦德', '毕尔巴鄂'],
#  ['北京建筑设计研究院', '北京市政府'],
#  ['ac米兰', '国米'],
#  ['浙江海宁市区'],
#  ['澳门', '飞檐'],
#  ['里昂', '佛罗伦萨', '拜仁', '德甲'],
#  ['建行'],
#  ['美国', '台协会', '布鲁京斯研究所东北亚政策'],
#  ['斯洛文', '阿根廷'],
#  ['利物浦', '国米'],
#  ['银联'],
#  ['沙尔克04队', '柏林赫塔队', '德甲'],
#  ['富勒姆', '尼美根'],
#  ['四川', '泸沽湖镇走婚桥岔路口', '博树村'],
#  ['印度'],
#  [],
#  ['博尔顿', '阿森纳'],
#  ['林肯公园', '纽约曼哈顿中央公园'],
#  ['蒜村'],
#  ['丽泽商务区'],
#  ['招商银行', '美国雷曼兄弟公司'],
#  ['阿尔梅'],
#  ['河南省网络文化协会', '郑州市文化市场管理办公室科长袁德顺', '郑州市网吧行业协会'],
#  ['gabbana', '英国'],
#  ['朴茨茅斯', '弗拉顿公园球场', '雷丁'],
#  ['热刺', '桑坦德'],
#  ['韩国电视台OnGameNet', 'WCG'],
#  ['重庆国际信托有限公司'],
#  ['WCG'],
#  ['博洛尼亚'],
#  ['润泽地产市场部'],
#  ['农行', '建行', '交行'],
#  ['银联商务湖北分公司'],
#  [],
#  [],
#  ['珠港港区', '美国海军', '深水军港'],
#  ['中储粮'],
#  ['东五环东'],
#  ['乌审草原'],
#  ['工', '农', '中', '建'],
#  ['沙尔克', '险沃尔夫'],
#  [],
#  ['广州商业银行', '唐山商业银行', '商业银行'],
#  ['中国银联', '泰国', '韩国', '新加坡'],
#  ['费内巴切', '波尔图'],
#  ['香港中银投资公司战略投资部', '中国信托业协会'],
#  ['曼城', '沙尔克', '曼联'],
#  ['中国光大银行沈阳分行'],
#  ['纽卡', '枪手'],
#  ['宝钢集团'],
#  ['切沃', '罗马'],
#  ['香港'],
#  ['立博', '德甲'],
#  ['门楼下乡学校', '门楼下乡野菜加工和竹鼠养殖产业基地', '三井学校等地'],
#  ['中粮集团', '益海嘉里', 'cbn'],
#  ['长沙市商业银行', '长沙市商业银行', '长沙市政府'],
#  ['北京东方君悦大酒店会议厅'],
#  ['孟加拉村'],
#  ['比勒菲尔德队', '多特蒙德队', '德甲'],
#  ['丽泽商务区', '北京市'],
#  ['布里塔尼亚'],
#  ['上海经贸学院', '松江大学城文汇路716号的樱花广场二楼'],
#  ['塞维利亚皇家'],
#  ['宝钢'],
#  ['中国嘉德'],
#  ['中东'],
#  ['基本法咨询委员会执行委员会', '香港特别行政区筹备委员会'],
#  ['比勒菲尔德', '布莱克本', '桑德兰', '英德足彩'],
#  ['韩国电视台OnGameNet', 'WCG'],
#  ['足彩', '维冈'],
#  ['深圳中安信业'],
#  ['深圳福彩', '深圳市福彩中心'],
#  ['丽泽'],
#  ['奥尔堡', '凯尔特'],
#  ['香港电影评论学会'],
#  ['骑士广场', '法国香榭大道'],
#  ['足彩', '英德'],
#  [],
#  ['博勒沃', '拜仁'],
#  ['巴勒莫'],
#  ['切沃', '乌迪内斯', '罗马', '国际米兰'],
#  ['波尔多小镇'],
#  ['蝙蝠'],
#  ['ac米兰', '立博', '意甲'],
#  ['浦东新区碧云', '东城'],
#  ['Gibea', '美国军', '国会'],
#  ['沙尔克04', '曼城'],
#  ['杭州丁桥辰秀嘉苑12幢1单元'],
#  ['子君村'],
#  ['奥萨苏纳队', '瓦拉多利德队', '西甲'],
#  ['曼联', '布莱克本'],
#  ['巴勒莫', '切沃'],
#  ['意甲', '罗马', '利沃诺'],
#  ['北京', '长安福特'],
#  ['香港', '英国政府'],
#  ['新华网', '深圳', '深圳发展银行'],
#  ['马洛卡队', '维尔瓦队', '西甲'],
#  ['工行'],
#  ['易纲'],
#  ['乌拉圭'],
#  [],
#  [],
#  ['佳士得', '苏富比', '香港'],
#  ['罗马', '莱切', '莱切'],
#  ['西南布', '贵州西南部', '黔', '滇', '桂三省区'],
#  ['霍芬海', '比勒菲'],
#  ['<酒店'],
#  ['加拉塔萨雷', '梅塔利斯特'],
#  ['立博'],
#  ['纽约'],
#  ['库塔', '印尼', 'delibistro'],
#  ['西甲'],
#  ['中国农业银行亚运村支行某分理处'],
#  ['Oa'],
#  ['莫斯科中央陆军', '波兹南', '拉科', '费耶诺德', '加拉塔萨雷', '梅塔利斯特'],
#  ['保险行业协会'],
#  ['英超'],
#  [],
#  ['英超', '伯纳乌球场'],
#  ['桑坦德'],
#  ['社区', '街道办'],
#  ['民生', '工行', '中心', '浦发', '中行', '交行', '农行', '民生', '建行'],
#  ['福利', '体育'],
#  ['联盟杯', '塞维利亚', '曼城', '乌迪内斯'],
#  ['ac米兰', '皇马'],
#  ['香港'],
#  ['公安大学'],
#  ['阿森纳'],
#  ['意甲', '热门'],
#  ['Gazillion', '好莱坞'],
#  ['奥斯卡'],
#  ['历藏公司'],
#  ['赐溥杰', '天津'],
#  ['赫尔城', '曼城'],
#  ['中央财经大学'],
#  ['尼美根', '荷甲', '莫斯科斯巴达'],
#  ['桑普多利亚', '斯图加特'],
#  ['渣打银行'],
#  ['塞利国家公园amboselip', '肯尼亚边境地区'],
#  ['民生银行信用卡中心'],
#  ['苏富比', '佳士得'],
#  ['徐阳西甲', '巴萨', '潜水艇'],
#  ['上海航空联办'],
#  ['WCG', 'WCG'],
#  ['某国有银行宝安支行'],
#  ['莫斯巴', '荷兰球队'],
#  ['Valve'],
#  ['广州', '广州'],
#  ['瓦拉多利德', '马略卡'],
#  ['德国达姆', '塔特市消防部门'],
#  ['bs分拆', '荷银'],
#  ['乌迪内斯'],
#  ['ECL'],
#  ['CPL'],
#  [],
#  ['长沙'],
#  ['北大西洋公约组织'],
#  ['GSL'],
#  ['俄超', '欧冠'],
#  ['俄国防部', '俄新社', '莫斯科', '列宁格勒军区', '西部战略司令部'],
#  ['福虹路', '招行'],
#  ['全明星高尔夫慈善公益赛', '湖州温泉高尔夫球场'],
#  ['阿森纳', '迪纳摩'],
#  ['中国信托业协会'],
#  ['韩亚银行', '北京金融大街17号韩亚银行营业部'],
#  ['越南', '特别行动组'],
#  ['西汉姆联', '博尔顿'],
#  ['破白宫', '五角大楼网络'],
#  ['“光耀东方广场'],
#  ['博尔顿', '切尔西', '足彩'],
#  ['纽约商品交易所'],
#  ['丽泽商务区', '北京经济社会', '丽泽商务区'],
#  ['交通银行（601328.sh）', '广发', '民生银行（600016.sh）'],
#  ['英超', '纽卡斯尔'],
#  ['链家地产市场研究部'],
#  ['cbd东'],
#  ['纽卡', '纽卡'],
#  [],
#  ['江西省宜春市保险行业协会', '邮储银行宜春分行', '邮储银行'],
#  [],
#  ['bwin', '意甲', 'bet365'],
#  ['中维拉', '富勒姆'],
#  ['意甲', '切沃队'],
#  ['北京'],
#  ['联赛'],
#  ['鲁能地产格拉斯小镇'],
#  ['重庆工商联'],
#  ['农行', '工', '中', '建'],
#  ['埃弗顿', '埃弗顿'],
#  ['皇家贝蒂斯队'],
#  ['广东发展银行'],
#  ['育碧'],
#  ['枪支试图', '2号大街上太阳食品店店'],
#  ['美国驻外使'],
#  ['波兰', 'bet365'],
#  ['沙尔克', '赫塔', '足彩'],
#  ['乌克兰'],
#  ['乌迪内斯', '切沃'],
#  ['丽泽商务区'],
#  ['桂园', '重庆'],
#  ['北京'],
#  ['Games联'],
#  ['西安电子科技大学'],
#  ['Eidos', '蒙特利尔'],
#  ['宝钢股份', '宝钢集团'],
#  ['贝尔格莱德游击队', '联盟杯'],
#  ['意甲', '桑普'],
#  ['意甲', '意甲'],
#  ['桑普多', 'eurobet'],
#  ['广州市寺右新马路4号之8长城大厦3楼'],
#  ['GSL', 'OSL', 'KeSPA'],
#  [],
#  ['瓦拉多利德', '皇马', '比利亚雷亚尔', '马洛卡'],
#  ['梅塔利斯', '乌克兰', '联盟杯'],
#  ['文化部', '商务部'],
#  ['源阅文集团军'],
#  [],
#  ['阿森纳'],
#  ['润泽地产', '新浪乐居', '润泽地产', '润泽悦溪', '润泽庄园', '新浪乐居'],
#  [],
#  ['landmarkchater', 'chanel'],
#  ['波鸿', '赫塔', '沃尔夫', '斯图加'],
#  ['ac米兰'],
#  ['北京', '北京'],
#  ['G联赛', '上海站'],
#  ['盖蒂信托'],
#  ['拜仁', '欧锦赛'],
#  ['博洛尼旗舰装饰装修工程公司'],
#  ['Disa'],
#  ['ief', '国家体育总局'],
#  ['三星', 'WCG2011杭州赛区'],
#  ['THQ', '俄国科'],
#  [],
#  ['丽泽金融商务区', '金泰地产大厦'],
#  ['招行', '招行'],
#  ['米德尔斯堡', '纽卡'],
#  ['英冠', '博彩公司', '赫尔城'],
#  ['不勒斯'],
#  ['北京市海淀区双榆树西里36号南楼5层中国扶贫基金会'],
#  ['中国水电地产'],
#  ['Valve公司'],
#  ...]

# %%
new_df = pd.DataFrame({'tag': tag_list})
new_df.to_csv('suubmit.csv', index=False)
