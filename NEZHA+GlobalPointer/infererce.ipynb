# %%
import pandas as pd
import numpy as np
import random
import torch
import torch.nn as nn
from tqdm import tqdm
from torch.utils.data import SequentialSampler, DataLoader
from transformers import BertTokenizer
from model import GlobalPointer, GlobalPointerNERPredictor

# %%
data_path = '../dataset/test.csv'
df = pd.read_csv(data_path, delimiter="\t")
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2657 entries, 0 to 2656
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2657 non-null   object
# dtypes: object(1)
# memory usage: 20.9+ KB
#                                               text
# 0          比如片子一开始说到的暴雪娱乐的作品有……CS……。其实我看到这个时也喷饭了，这
# 1                               辽宁14家城商行开始执行央行房贷政策
# 2  而本场面对西布朗这样一支弱队，相信维冈不会放过这样的机会。目前，风扬数据下，由于平值从中阻隔，
# 3                          《辐射》设计师Anderson转投inXile
# 4   中信晒卡是一张个性十足的借记卡，中信银行网站为其提供了一个特色操作平台，客户通过简单的操作，

# %%
from config import parse_args

args = parse_args()
def setup_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
setup_seed(args.seed)


args.tag2idx = {'O':0, 'B-0':1, 'I-0':2}
args.idx2tag = {0: 'O', 1: 'B-0', 2:'I-0'}

# %%
# test_data


from ark_nlp.model.ner.global_pointer_bert import Tokenizer
tokenizer = BertTokenizer.from_pretrained(args.bert_dir)
ark_tokenizer = Tokenizer(vocab=tokenizer, max_seq_len=128)
import os
from ark_nlp.factory.utils.conlleval import get_entity_bio



Ent2id, id2Ent = {'0': 0, 'O': 1}, {0: '0', 1: 'O'}

# %%
if torch.cuda.is_available():
    args.device = 'cuda:0'
    print('使用：', args.device,' ing........')

model = GlobalPointer(args, len(Ent2id), 64).to(args.device)  #
path = f'./save_model/best_model.pth'
model.load_state_dict(torch.load(path, map_location='cpu'))
model=model.to(args.device)
# Out:
# 使用： cuda:0  ing........
# Some weights of the model checkpoint at ../hfl/chinese-roberta-wwm-ext were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.eval()
ner_predictor_instance = GlobalPointerNERPredictor(model, ark_tokenizer, Ent2id, tokenizer)

from tqdm import tqdm

predict_results = []

for i in tqdm(range(len(df))):
    _line = df['text'][i]
    label = len(_line) * ['O']
    for _preditc in ner_predictor_instance.predict_one_sample(_line):
        if 'I' in label[_preditc['start_idx']]:
            continue
        if 'B' in label[_preditc['start_idx']] and 'O' not in label[_preditc['end_idx']]:
            continue
        if 'O' in label[_preditc['start_idx']] and 'B' in label[_preditc['end_idx']]:
            continue

        label[_preditc['start_idx']] = 'B-' + _preditc['type']
        label[_preditc['start_idx'] + 1: _preditc['end_idx'] + 1] = (_preditc['end_idx'] - _preditc[
            'start_idx']) * [('I-' + _preditc['type'])]

    predict_results.append(label)
# Out:
# 100%|██████████| 2657/2657 [00:27<00:00, 96.36it/s]

# %%
print(len(predict_results))
#%
# Out:
# 2657

# %%
from ark_nlp.factory.utils.conlleval import get_entity_bio
def extract_entity(label, text):
    entity_labels = []
    for _type, _start_idx, _end_idx in get_entity_bio(label, id2label=None):
        entity_labels.append({
            'start_idx': _start_idx,
            'end_idx': _end_idx,
            'type': _type,
            'entity': text[_start_idx: _end_idx + 1]
        })
    entity_list = []
    for info in entity_labels:
        entity_list.append(info['entity'])
    return entity_list

# %%
tag_list = []
for idx, label in enumerate(predict_results):
    tag_list.append(extract_entity(label=label, text=df['text'][idx]))

# %%
tag_list
# Out:
# [['暴雪娱乐'],
#  ['辽宁'],
#  ['西布朗', '维冈'],
#  ['inXile'],
#  ['中信', '中信银行'],
#  ['欧冠', '联盟杯'],
#  ['星展银行香港分行'],
#  ['民生蓝筹混合型基金', '民生加银'],
#  ['北京澳际教育咨询有限公司', '澳新亚留学中心'],
#  ['老特拉福德', '切尔西', '曼联'],
#  ['柳州'],
#  ['布莱克本'],
#  ['拉科', '马拉加'],
#  ['挪威', '荷兰'],
#  ['华纳兄弟公司'],
#  ['网龙'],
#  ['上海正大广场'],
#  ['盛大'],
#  ['博洛尼亚'],
#  ['光大'],
#  ['西南证券办公室'],
#  ['欧足联'],
#  ['阿森纳', '基辅迪纳摩'],
#  ['波尔多小镇一期'],
#  ['科隆', 'IEM5世界总决赛'],
#  ['宜昌高新区港窑路25号南苑二期14栋南都御景1号楼12楼46-1-148'],
#  ['罗布泊西北岸'],
#  ['苏格兰', '意大利'],
#  ['塞维利亚', '皇马', '马竞'],
#  ['切尔西', '罗马'],
#  ['邙山', '长安', '陈仓'],
#  ['辉煌云上', '辉煌集团'],
#  ['北三环马甸桥', 'cbd'],
#  ['摩根大通'],
#  ['宝钢股份'],
#  ['意甲'],
#  ['798工厂'],
#  ['荷兰', 'nec尼美根'],
#  ['雷曼兄弟'],
#  ['英国伦敦', 'Candella'],
#  ['印尼', '奥地利'],
#  ['纽卡斯尔', '热刺'],
#  [],
#  ['南昌市兴业银行'],
#  ['华夏'],
#  ['梅塔利斯特'],
#  ['意甲球队', '联盟杯'],
#  ['民生银行'],
#  ['广东东莞市万江区东莞市万江街道生益电子厂'],
#  ['曜越太阳神跑跑战队'],
#  ['那不勒斯', '卡利亚里'],
#  ['德国复兴信贷银行'],
#  ['中国航天科技集团'],
#  ['萨尔瓦多'],
#  ['ac米兰', '拉齐奥'],
#  ['曼城', '英超'],
#  ['imf'],
#  ['吉隆滩'],
#  [],
#  ['太阳神', '橘子熊'],
#  ['波斯湾', '霍尔木兹海峡水域'],
#  ['芬兰'],
#  ['广发行'],
#  ['中国国际数码互动娱乐展览会', '上海国际博览中心'],
#  ['波鸿', '赫塔', '沃尔夫', '斯图加'],
#  ['BBFC'],
#  [],
#  ['努曼西亚', '西班牙人', '马德里竞技', '拉科'],
#  ['兴业银行', '甘肃信托'],
#  ['河南省网络文化协会', '郑州市文化市场管理办公室', '郑州市网吧行业协会'],
#  ['理想国际大厦8层新浪乐居嘉聊室'],
#  ['乌迪内斯', '莫斯科斯巴达克'],
#  ['莱切', '罗马'],
#  ['清华大学'],
#  ['台彩'],
#  ['人保财险'],
#  ['深发展'],
#  ['石景山ECL场馆'],
#  ['香港'],
#  ['法新社', '远东地区'],
#  ['香港', '维多利亚港'],
#  ['里昂', '巴黎', '佛罗伦'],
#  ['华润置地', '（北京）股份有限公司'],
#  ['南京', '江苏省苏州', '常州'],
#  ['卡利亚里', '森普多利亚'],
#  ['纽约'],
#  ['工行'],
#  ['沙尔克04', '曼城'],
#  ['切尔西', '英超', '斯坦福桥球场'],
#  ['民生银行'],
#  ['英超'],
#  ['意甲'],
#  [],
#  ['舒畅园', '津滨大道南侧'],
#  ['那不勒斯', '热那亚'],
#  ['9号楼1单元13楼166号朝西方向'],
#  ['北京保利', '俏江南'],
#  ['龚龚云集超市'],
#  ['保加利亚'],
#  ['学校', '学生公寓', '教委'],
#  ['川迪'],
#  ['北京展览馆', '中关村'],
#  ['尤文'],
#  ['上海', '北京', '深圳', '成都'],
#  ['拉科鲁尼亚队', '马拉加队', '西甲'],
#  ['锡耶纳', '都灵'],
#  ['台湾'],
#  ['乌迪内', '意甲', '联盟杯'],
#  ['泸州老窖', '中海地产'],
#  ['布里斯班', '摩顿岛'],
#  ['索马里海域', '联合国安理会'],
#  ['威尼斯'],
#  ['足彩', '米兰', '罗马'],
#  [],
#  ['桑坦德'],
#  ['金星展区'],
#  ['河南省郑州市七彩商都网吧'],
#  ['新加坡'],
#  ['上海光大会展中心'],
#  ['西山林语'],
#  ['上海'],
#  ['罗马', '紫百合'],
#  ['马来西亚'],
#  ['奥兰多'],
#  ['威尼斯'],
#  ['EA'],
#  ['沙尔克', '阿森纳'],
#  ['宝钢集团'],
#  ['大使馆', '中国'],
#  ['星展银行私人银行', 'san-hot公司'],
#  ['热刺'],
#  ['交通银行'],
#  ['Valve'],
#  ['bac', '美国政府'],
#  ['切沃', '罗马'],
#  ['日本', '韩国', '中国'],
#  ['招商银行', '平安银行'],
#  ['中国人民银行'],
#  ['英超'],
#  ['西岗村'],
#  ['美泰', '加拿大地区'],
#  ['中国外汇交易中心'],
#  ['伦敦', '富勒姆', '西汉姆'],
#  ['凯尔特人', '欧冠'],
#  ['斯图加特'],
#  ['北京银联信', '招商银行', '工商银行'],
#  ['广州市林和西路广州体育学院东门体育馆'],
#  ['喀布尔', '阿富汗'],
#  ['福彩中心'],
#  ['金融街', '丽泽商务区'],
#  ['联赛', '赫尔城'],
#  ['阿尔及利亚'],
#  ['绿城集团'],
#  ['嘉陵江', '渝中半岛'],
#  ['切沃'],
#  ['育碧公司'],
#  ['中国政法大学民商经济法学院'],
#  ['保险行业协会'],
#  ['邮储银行宜春市分行', '邮储银行江西省分行'],
#  ['金管局', '东亚银行'],
#  ['拜仁', '佛罗伦'],
#  ['渣打银行'],
#  ['拜仁'],
#  ['皇马'],
#  ['中国信托业协会'],
#  ['活色生香的工体西路'],
#  ['鸿业兴园'],
#  [],
#  ['曼城'],
#  ['interwetten', '热刺'],
#  ['拉齐奥', '热那亚'],
#  ['希洪'],
#  ['北大法学院'],
#  ['区信访办'],
#  ['CrypticStudios'],
#  ['阿森纳'],
#  ['香港贸易发展局', '寰宇娱乐', '骄阳电影', '美亚电影', '寰亚综艺', '东方电影'],
#  ['赫尔城'],
#  ['桑坦德竞技', '西班牙人'],
#  ['yahoo', '烂番茄'],
#  ['马里布'],
#  ['凯尔特人', '国米'],
#  ['美国政府', '伞公司'],
#  ['曼城', '巴黎圣日耳曼'],
#  ['罗马', '切尔西'],
#  ['维冈'],
#  ['阿尔梅利亚', '奥萨苏纳'],
#  ['北京朝阳区'],
#  ['加拉塔萨雷'],
#  ['广州市十三行新中国大厦楼0档工行'],
#  ['PeopleCan'],
#  ['联盟杯'],
#  ['农业银行', '建设银行'],
#  ['上海'],
#  ['好莱坞'],
#  ['尼美根'],
#  ['西哈努克外海域'],
#  ['澳彩', '拉齐奥'],
#  ['EA公司'],
#  ['银狐'],
#  ['博洛尼'],
#  ['沙尔克', '切尔西'],
#  ['汉堡', '斯图加特', '欧冠', '联盟杯'],
#  ['华贸中心', '东长安街', '华贸城'],
#  [],
#  ['通州'],
#  ['阿森纳'],
#  ['央行上海总部'],
#  ['成都'],
#  ['瓦伦西', '米兰'],
#  ['不来梅'],
#  ['尼美根', '莫斯科斯巴达'],
#  [],
#  ['纽约'],
#  ['欧冠'],
#  ['英超'],
#  ['奥斯泰华'],
#  ['广发行'],
#  ['里昂'],
#  ['快钱公司'],
#  ['Midway'],
#  ['那不勒斯', '立博'],
#  ['欧冠'],
#  ['中房协', '中介企业'],
#  ['威廉', 'ssp'],
#  ['深圳平安银行'],
#  ['京西商务区', '丽泽商务区'],
#  ['光大银行深圳分行信用卡中心'],
#  ['行业协会'],
#  ['上海', '无锡', 'CEC国际电子竞技冠军杯'],
#  ['标准列日', '桑普多利亚'],
#  ['伟德', 'bet365'],
#  ['北京'],
#  ['北京住房公积金管理中心', '北京市'],
#  ['苏园'],
#  ['布莱克本', '利物浦'],
#  ['阿森纳', '基辅'],
#  ['热那亚'],
#  ['育碧'],
#  ['东京'],
#  ['LGD', 'G联赛'],
#  ['丽泽'],
#  ['阿里巴巴'],
#  ['奥斯卡战线', '威尼斯电影节', '罗马电影节'],
#  ['英超', '富勒姆', '德比郡', 'interwetten'],
#  ['埃伍德公园球场”', '枪手'],
#  [],
#  ['英国伦敦', 'Candella'],
#  ['印度空间组织', '中央政府'],
#  [],
#  ['朝阳区定福庄'],
#  ['国有银行', '交通银行'],
#  ['宝华工贸中心'],
#  ['中信新城', '东南五环', '亦庄核心生活区西侧'],
#  ['农行', '交行'],
#  ['深发展信用卡中心'],
#  ['wcg', '北京大学百年讲堂'],
#  ['卡尔斯', '赫尔城', '纽卡斯'],
#  ['millennium', '美国证券交易委员会'],
#  ['橘子熊'],
#  ['热那亚'],
#  ['光大银行长春分行'],
#  ['乐居', 'btv财经频道'],
#  ['东南五环光机电产业基地核心区'],
#  ['皇家邮政'],
#  ['网元网'],
#  [],
#  ['北京'],
#  ['邮储'],
#  ['accumulator', '香港证监会', '金管局'],
#  ['花旗集团'],
#  ['castle', '渣打银行'],
#  ['人居环境委员会中华环境保护基金会', '中国人居环境专项基金'],
#  ['花旗'],
#  ['宁波银行', '中国银行', '招商银行', '广发银行', '浦发银行', '交通银行'],
#  ['韩国星际争霸1'],
#  ['ParadoxInteractive'],
#  ['丽泽商务区'],
#  ['加拉塔', '奥林匹', '本菲卡', '阿里·萨米扬球场'],
#  ['中国人民银行'],
#  ['赫尔城', '维冈'],
#  ['德甲'],
#  ['加拉塔萨雷'],
#  ['泽尼特', '尤文图斯'],
#  ['KR', '华义SPIDER'],
#  ['拉科', '马德里', '毕尔巴鄂', '奥萨苏纳'],
#  ['石家庄', 'G联赛'],
#  ['桑坦德竞技队', '毕尔巴鄂竞技队', '西甲'],
#  ['招商银行', '兴业银行', '中信银行'],
#  ['建设银行'],
#  ['农村信用社'],
#  ['证监会', '渣打'],
#  ['上海国家会计学院'],
#  ['西泠印社秋季拍卖会', '杭州'],
#  ['联盟杯', '奥林匹亚科斯', '本菲卡', '加拉塔萨雷'],
#  ['意甲'],
#  ['子君村'],
#  ['西部拉贾斯坦邦'],
#  ['富力湾'],
#  ['亚庇东南海域'],
#  ['暴雪', '美国'],
#  ['尼美根', '荷甲', '华伦丹'],
#  ['尤文', '马拉加'],
#  ['“光耀东方广场”'],
#  [],
#  ['广州'],
#  ['罗马'],
#  ['罗马'],
#  ['吉中乡'],
#  ['仙本', '斗湖'],
#  ['missionbeach', '凯恩斯市外南部'],
#  ['中国电子大厦'],
#  ['地方美术家协会'],
#  ['建行', '招行'],
#  ['吉林长春连邦长春市工农大路1128号欧亚7214室'],
#  ['西布朗'],
#  ['建行佛山分行'],
#  ['建行'],
#  ['纽卡斯尔队', '斯托克城队', '英超联赛'],
#  ['张家口崇礼县'],
#  ['Westwood公司'],
#  [],
#  ['北邙山'],
#  ['G联赛'],
#  ['国家美术馆'],
#  ['联盟杯'],
#  ['尼美根队', '托特纳姆队'],
#  ['米德尔斯堡', '欧文'],
#  ['联盟杯'],
#  ['英超', '意西足彩'],
#  ['拉科', '毕尔巴鄂', '奥萨苏纳'],
#  ['工商银行'],
#  ['海淀区'],
#  ['曼彻斯特', '曼联'],
#  ['武汉安胜花园', '青山碧苑四期'],
#  ['中国银行', '招商银行', '交通银行'],
#  ['招行'],
#  ['北京家具协会'],
#  ['中国银行'],
#  ['乌迪内斯'],
#  ['美国', '美国空军'],
#  ['乐成中心b座21层'],
#  ['名流尊邸', '涿州市政广场南侧，平安北街与华阳路交叉处向东'],
#  ['孟买'],
#  ['CCM'],
#  ['汇丰'],
#  ['济南'],
#  ['银联商务湖北分公司'],
#  ['visa'],
#  ['北京大观园'],
#  ['芷锚湾'],
#  ['北京', 'cbd', '百子湾', '朝阳公园', '中关村'],
#  ['日本橡胶贸易协会'],
#  ['中信嘉华银行', '信贷风险管理委员会'],
#  ['巴塞罗那市中心', 'larocavillage购物村'],
#  ['老挝家具协会'],
#  ['博宝艺术网宝珍商城'],
#  [],
#  ['Take-Two', 'FTC'],
#  ['WCG', '湖北卫视'],
#  ['WCG'],
#  ['法兰克福队', '波鸿队'],
#  ['维拉', '阿森纳', '曼联'],
#  ['切沃', '锡耶纳'],
#  ['农村信用社'],
#  ['中金公司'],
#  ['UD'],
#  ['新浪乐居'],
#  ['深圳', '深圳发展银行'],
#  [],
#  ['海淀区知春路', 'Falcom'],
#  ['匡时', '西泠印社'],
#  ['招商银行', '北京银行', '浦发银行', '民生银行', '光大', '华夏'],
#  ['世嘉', '黑曜石工作室'],
#  ['司法部门', '人民银行'],
#  ['桑普多', '卡塔尼'],
#  ['埃弗顿', '西汉姆'],
#  ['PLU娱乐传媒'],
#  ['NirvanaDota战队'],
#  [],
#  [],
#  ['平安银行'],
#  ['宏村'],
#  ['日尔曼', '威廉'],
#  ['某国有银行广州分行'],
#  ['沈阳市'],
#  ['深发展'],
#  ['江城', '东亚银行'],
#  ['中行'],
#  ['图阿普谢', '俄罗斯南部', '黑海'],
#  ['澳际出国留学澳新亚留学中心'],
#  [],
#  ['ac米兰', '雷吉纳'],
#  ['CCM', 'PanDa战队'],
#  ['博彩公司', '不来克本'],
#  ['湖南省', '潇湘银行'],
#  ['宝钢'],
#  ['荷银', '中国北京', '上海', '深圳', '成都'],
#  ['安监局', '建设厅', '质监局', '人力保障厅', '建协'],
#  ['eswc2009grandfinal'],
#  ['英冠', '赫尔城'],
#  ['谷歌'],
#  ['中房协'],
#  ['欧佩克'],
#  ['工商银行', '江岸区法院'],
#  ['英超'],
#  ['卡利亚里'],
#  ['红军', '勒沃', '枪手', '米堡'],
#  ['广发行'],
#  ['新疆', '四川地震灾区'],
#  ['北京保利拍卖公司'],
#  ['ac米兰'],
#  ['oGs战队'],
#  ['大司马工作室'],
#  ['北京'],
#  ['香港'],
#  ['THQ', 'BigHugeGames工作室'],
#  ['孟买', '印度中央机械工程研究所'],
#  ['贝蒂斯', '瓦伦'],
#  ['欧洲杯'],
#  ['中华全国集邮联合会', '山东省集邮协会'],
#  ['邮储北分行'],
#  ['门兴', '勒沃库森'],
#  ['拉科', '西甲', '费耶诺德', '荷甲', 'interwetten'],
#  ['幸福谷happyvalley以北'],
#  ['切沃', '罗马'],
#  ['维冈'],
#  ['不来梅'],
#  ['工行'],
#  ['德州扑克'],
#  ['拜仁慕尼黑'],
#  ['燕郊区域'],
#  ['拉科鲁', '毕尔巴', '费耶诺德'],
#  ['香港'],
#  ['湖南省金融办'],
#  ['德国政府'],
#  ['世博会', '伦敦', '伦敦的水晶宫'],
#  ['省联社'],
#  ['夏威夷水岸1号'],
#  ['博尔顿'],
#  ['翡翠收藏俱乐部'],
#  ['ac米兰'],
#  ['法国'],
#  ['香港'],
#  ['中国银行', '湖南信托', '商业银行', '甘肃信托'],
#  ['沙尔克', '沃尔夫', '狼堡'],
#  ['中国银联公司'],
#  ['沙荷路', '堆芳行'],
#  ['k2地产'],
#  ['印度南部班加罗尔空军基地'],
#  ['马拉加'],
#  ['斯托克'],
#  ['罗森博格队', '瓦伦西亚队'],
#  ['黄山大门', '南大门汤口镇'],
#  ['大宇公司', '北京软星'],
#  ['桑德兰'],
#  ['欧冠', '莫斯科斯巴达克', '费内巴切', '波尔图'],
#  ['南连金融街', '中关村'],
#  ['江苏电视台'],
#  ['越南', '乌拉尔山脉'],
#  ['洛杉矶'],
#  ['纽约'],
#  ['澳彩'],
#  ['紫百合'],
#  ['北京华太'],
#  ['橘子熊'],
#  ['中国'],
#  ['热刺'],
#  ['宣明典居卖场'],
#  ['米兰', '恩波利', '罗马'],
#  ['金科帕提欧', '清华大学建筑学院'],
#  ['曼联'],
#  ['美国'],
#  ['银联'],
#  ['足彩'],
#  ['4K', 'MYM', 'EG战队'],
#  ['罗马', '利物浦'],
#  ['山西省银行业协会'],
#  ['立博'],
#  ['建行'],
#  ['法新社', '法国', '国家队'],
#  ['好莱坞商会', '星光大道'],
#  ['三菱东京日联银行'],
#  ['中国投洽会', '天津', '北京'],
#  ['工行'],
#  ['交通银行'],
#  ['尤文', '马拉加'],
#  ['曼联', '阿森纳', '勒沃沙尔克'],
#  ['希洪', '贝蒂斯'],
#  ['曼城', '沙尔克'],
#  ['工艺行业协会'],
#  ['厄普顿公园'],
#  ['花旗中国'],
#  [],
#  ['西山'],
#  ['维旺迪集团'],
#  ['嘉泰'],
#  ['招行武汉分行'],
#  ['马尔代夫', '香格里拉岛', '香格里拉酒店集团'],
#  ['荷兰', '冰岛'],
#  ['桑普', '联盟杯', '卡塔尼亚'],
#  ['那不勒斯'],
#  ['英超', '斯托克城'],
#  ['切沃', '博尔顿'],
#  ['福克斯公司'],
#  ['中国人民大学行政管理学研究所'],
#  ['游港杯', '浙江缔顺科技有限公司游戏港口团队'],
#  ['昌乐路文化市场'],
#  ['索尼'],
#  ['太平洋中心'],
#  ['金融街', '三里河', '丽泽商务区'],
#  ['婆罗洲'],
#  ['SCEA'],
#  ['北京'],
#  ['中信银行'],
#  ['阿森纳', '欧冠'],
#  ['北京南区', '金融街'],
#  ['华谊兄弟'],
#  ['斯图加特'],
#  ['门兴', 'bet365', '澳彩'],
#  ['纽卡'],
#  ['切尔西', '曼城'],
#  ['EA'],
#  ['农商行'],
#  ['中国银行（601988.sh）', '工商银行（601398.sh）'],
#  ['金融街'],
#  ['福彩'],
#  ['马略卡', '维尔瓦'],
#  ['新浪乐居地产名人高尔夫球赛', '辉煌国际高尔夫球俱乐部'],
#  ['巴西', '维拉公园'],
#  ['供销社', '农业合作社', '农村信用社'],
#  ['帕纳辛奈科斯', '联盟杯'],
#  ['香港分行'],
#  ['韩亚银行', '韩国友利银行（中国）有限公司'],
#  [],
#  ['海渔广场'],
#  ['桑普蓝鹰', '罗马'],
#  ['西甲', '努曼西', '维拉利'],
#  ['快客', '金象大药房', '我爱我家中介'],
#  ['招行信用卡中心'],
#  ['中博传媒', '家乐电影'],
#  ['纽卡斯', '赫尔城'],
#  ['乌迪内斯', '拉齐奥', '罗马'],
#  ['北京', '北京当代moma空中连廊会所'],
#  ['英超'],
#  ['洛杉矶会展中心'],
#  ['兴业银行'],
#  ['外资银行'],
#  ['上海国家会计学院'],
#  ['乌迪', '切沃'],
#  ['中国电子竞技运动发展中心'],
#  ['桑德兰'],
#  ['洛杉矶国际会议中心'],
#  ['都灵'],
#  ['四川', '社科院'],
#  ['北京娱乐通', '游戏天堂'],
#  ['仓储物流协会'],
#  ['成都泰和泰律师事务所'],
#  ['曼城', '阿森纳'],
#  ['卡尔斯鲁厄队', '云达不来梅队', '德甲'],
#  ['利物浦', '西汉姆'],
#  ['农行'],
#  ['ac米兰'],
#  ['招行'],
#  ['重庆国际信托'],
#  ['长滩岛', '东南亚'],
#  ['米德尔', '威廉希尔'],
#  ['台湾宇珍国际艺术有限公司'],
#  ['THQ'],
#  ['rbs', '荷兰银行'],
#  ['魁北克彩票机构'],
#  ['丰台区区委办公室'],
#  ['都灵'],
#  ['联盟杯'],
#  ['北京'],
#  ['长江二桥'],
#  ['富勒姆', '英超', '维拉'],
#  ['斯巴达人', '基辅迪纳摩', '欧冠', '奥斯特拉华'],
#  ['荣田路', '大工业区中心区的南部', '丹梓东路', '临惠路'],
#  ['彩票监管部门'],
#  ['中信银行深圳分行信用卡中心', '人民银行深圳分行'],
#  ['G联赛'],
#  ['北京', '央行'],
#  ['深发展', '广发'],
#  ['伯纳乌球场', '皇马'],
#  ['中国珠宝玉石首饰行业协会'],
#  ['汉雅轩'],
#  ['成都'],
#  ['沙尔克04队', '柏林赫塔队'],
#  ['伦敦', '博尔顿'],
#  ['桑德兰'],
#  ['洞爷', '登别'],
#  ['威廉希尔'],
#  ['美国'],
#  ['安徽省皖农贸易有限公司'],
#  ['新闸路石门路银行'],
#  ['西甲', '巴萨', '皇马'],
#  ['北京'],
#  [],
#  ['丽泽金融商务区'],
#  ['台湾'],
#  ['门兴', '科特布斯', '勒沃', '拜仁'],
#  ['林达海渔广场'],
#  ['招行'],
#  ['联盟杯'],
#  ['费内巴', '波尔图'],
#  ['农行', '杭州'],
#  ['布莱克本队', '利物浦队'],
#  ['merchantsbank'],
#  ['连天红'],
#  ['世纪佳缘'],
#  ['巴西'],
#  ['金贸中心'],
#  ['红海', '埃及', '伊甸园'],
#  ['湖北蕲春县', '北京', '杭州', '上海', '广州'],
#  ['雷吉纳', '紫百合'],
#  ['新浪乐居地产名人高尔夫球赛', '辉煌国际高尔夫球俱乐部'],
#  ['深发展信用卡中心'],
#  ['wcg'],
#  ['南美洲', '密西西比河'],
#  ['合生世界村', '马驹桥镇', '金桥科技产业基地'],
#  ['渣打'],
#  ['中国农业银行', '银联'],
#  ['纽卡', '俱乐部'],
#  ['波尔多', '切尔西'],
#  ['重庆市渝中区建委开发办'],
#  ['莱切'],
#  ['甘肃省甘南藏族自治州', '北京'],
#  ['意大利'],
#  ['复旦大学金融学院'],
#  ['保加利亚'],
#  ['布莱克本'],
#  ['皇马'],
#  [],
#  ['新浪彩票频道'],
#  ['喀山鲁宾', '莫陆军'],
#  ['北京市丰台区京荟广场文化产业园B座2层'],
#  ['澳际教育集团英国留学中心'],
#  ['加利福尼亚州阿纳海姆'],
#  ['巴斯克人'],
#  [],
#  ['上海国家会计学院'],
#  ['伯恩利'],
#  ['皇马'],
#  ['博尔顿'],
#  ['lv'],
#  ['桑德兰'],
#  ['尤文'],
#  ['postcomm', '皇家邮政'],
#  ['莱切', '罗马'],
#  ['美国弗吉尼亚大学建筑系'],
#  ['拉科鲁尼亚队'],
#  ['广州'],
#  ['纽卡斯尔队', '斯托克城队', '英超联赛'],
#  ['富勒姆'],
#  ['钢铁人', 'KR'],
#  ['赵王府'],
#  ['博联网络天马店（曙光中路248号曙光大邸二楼'],
#  ['中国银联'],
#  ['深发展'],
#  ['易居房地产研究院', '政府部门'],
#  ['巴勒莫', '雷吉纳'],
#  ['西河沿甲215号'],
#  ['交行总行'],
#  ['索维娅国际艺术村'],
#  ['美国在台协会', '现华府智库布鲁京斯研究所'],
#  ['维冈'],
#  ['奇才', '麦迪逊广场花园', '尼克斯'],
#  ['乌迪内斯', '切沃'],
#  ['宁波市政府'],
#  ['博洛尼', '意甲'],
#  ['中华人民共和国新闻出版总署科技与数字出版司'],
#  ['贝尔格莱德游击', '标准列日'],
#  ['DragonForce'],
#  ['辽宁大连智星大连市沙河口区长兴电子城3楼E区74-1'],
#  ['暴雪', '九城'],
#  ['桑普多利亚', '标准列日'],
#  ['保监会'],
#  ['俄罗斯'],
#  ['EidosInteractive'],
#  ['莫斯科中央陆军', '联盟杯'],
#  ['中钢协'],
#  ['深圳平安银行', '光大银行'],
#  ['曼联'],
#  ['住房保障部门', '居委会', '派出所'],
#  ['银行业监督管理委员会', '美国'],
#  ['多特蒙德'],
#  ['武昌区徐东花市', '武青四干道'],
#  ['香港', '招商银行', '华夏银行'],
#  ['KeSPA', '暴雪', 'GomTV'],
#  ['英超'],
#  ['英超', '阿森纳队'],
#  ['贝蒂斯', '瓦伦'],
#  ['台湾'],
#  ['莱切'],
#  ['雷吉纳队', '博洛尼亚队', '意甲'],
#  ['王府井新华书店'],
#  ['都灵'],
#  ['欧冠', '曼城'],
#  [],
#  ['南师大', '江苏省文联党组'],
#  ['工行北京', '上海'],
#  ['韩亚银行', '中国', '山东'],
#  ['娱乐通'],
#  ['dtalipapa市场', '长滩岛'],
#  ['EA'],
#  ['北京大学法学院'],
#  ['日本', '中国'],
#  ['米堡'],
#  ['布莱克本'],
#  ['新浪财经', '中国保险学会', '保险经理人'],
#  ['重庆银行'],
#  ['ticabodivingcentre'],
#  ['刀锋工作室', '莫斯科斯巴达'],
#  ['赫特潟湖', '澳大利亚', '科宁公司', 'cogniscompany'],
#  ['广州易联商业服务有限公司', '“易联公司”'],
#  ['北京'],
#  [],
#  ['伟业顾问', '华远', '九都汇'],
#  ['莱切'],
#  ['盖蒂基金会'],
#  ['盖蒂博物馆', '盖蒂研究所', '盖蒂基金会', '盖蒂信托'],
#  ['华润置地'],
#  ['阿尔梅'],
#  ['西汉姆'],
#  ['热刺'],
#  ['广发行', '中信保'],
#  ['北京'],
#  ['中国集邮总公司'],
#  ['Relic'],
#  ['星展银行'],
#  ['东亚银行'],
#  ['CPL'],
#  ['荷甲', '沙尔克04'],
#  ['曼联'],
#  ['古巴'],
#  ['新长城', '山西代县'],
#  ['益海嘉里'],
#  ['上海黄金交易所'],
#  ['北京消防局', '央视'],
#  ['渣打', '贝发集团', '印度工程公司'],
#  ['联赛', '沙尔克', '德甲'],
#  ['拉齐奥'],
#  ['GameSpot'],
#  ['建行'],
#  ['中信银行', '南京银行', '兴业银行', '深发展'],
#  ['北京', '中国华夏易经研究会', '中国姓名文化研究会'],
#  ['银行业协会'],
#  ['官方组委会', 'G联赛'],
#  ['可口可乐', 'artyplan', 'sport'],
#  ['纽卡', '切尔西'],
#  ['联盟杯'],
#  ['曜越太阳神'],
#  ['尼罗河'],
#  ['塔内加航天空军基地'],
#  ['暴雪嘉年华', '美国加州阿纳海姆会议中心'],
#  ['湖州'],
#  ['招行'],
#  ['阿森纳', '维冈'],
#  ['桑坦德', '毕尔巴鄂'],
#  ['北京建筑设计研究院', '北京市政府'],
#  ['ac米兰', '国米'],
#  ['浙江海宁市区'],
#  ['澳门'],
#  ['里昂', '佛罗伦萨', '拜仁', '德甲'],
#  ['建行', '银监会'],
#  ['美国在台协会', '现华府智库布鲁京斯研究所'],
#  ['斯洛文', '阿根廷'],
#  ['利物浦', '国米'],
#  ['银联', '东亚（中国）'],
#  ['沙尔克04队', '柏林赫塔队'],
#  ['富勒姆', '尼美根'],
#  ['四川', '博树村'],
#  ['印度', '美国'],
#  ['国航'],
#  ['博尔顿', '阿森纳'],
#  ['林肯公园', '纽约曼哈顿中央公园'],
#  ['蒜村'],
#  ['丽泽商务区'],
#  ['招商银行', '美国雷曼兄弟公司'],
#  ['阿尔梅'],
#  ['河南省网络文化协会', '郑州市文化市场管理办公室', '郑州市网吧行业协会'],
#  ['gabbana', '英国'],
#  ['朴茨茅斯', '弗拉顿公园球场', '雷丁'],
#  ['热刺', '桑坦德'],
#  ['WCG'],
#  ['重庆国际信托有限公司'],
#  ['WCG'],
#  ['博洛尼亚'],
#  ['润泽地产'],
#  ['农行', '建行', '交行'],
#  ['银联商务湖北分公司'],
#  ['埃及'],
#  ['马耳他'],
#  ['珍珠港港区', '美国海军'],
#  ['中储粮', '国有粮库'],
#  ['东五环东坝商圈', '首开·常青藤'],
#  ['乌审草原'],
#  ['工', '农', '中', '建', '交'],
#  ['沙尔克', '沃尔夫', '狼堡'],
#  ['麒麟'],
#  ['广州商业银行', '唐山商业银行', '城市商业银行'],
#  ['中国银联', '泰国', '韩国', '新加坡'],
#  ['费内巴切', '波尔图'],
#  ['中国信托业协会'],
#  ['曼城', '沙尔克', '曼联'],
#  ['中国光大银行沈阳分行'],
#  ['纽卡', '枪手'],
#  ['宝钢集团', '伦敦金属交易所'],
#  ['切沃', '罗马'],
#  ['香港'],
#  ['德甲'],
#  ['门楼下乡学校', '门楼下乡野菜加工和竹鼠养殖产业基地、三井学校等地'],
#  ['中粮集团', '益海嘉里'],
#  ['长沙市政府'],
#  ['北京东方君悦大酒店会议厅'],
#  ['印度边防部队'],
#  ['比勒菲尔德队', '多特蒙德队', '德甲'],
#  ['丽泽商务区'],
#  ['布里塔尼亚球场'],
#  ['上海经贸学院', '松江大学城文汇路716号的樱花广场二楼'],
#  ['塞维利亚皇家骑士俱乐部斗牛场'],
#  ['宝钢'],
#  ['中国嘉德'],
#  ['中东'],
#  ['基本法咨询委员会执行委员会', '香港特别行政区筹备委员会'],
#  ['比勒菲尔德', '布莱克本', '桑德兰', '英德足彩'],
#  ['WCG'],
#  ['足彩', '维冈'],
#  ['深圳中安信业'],
#  ['深圳福彩', '深圳市福彩中心'],
#  ['丽泽'],
#  ['奥尔堡', '凯尔特'],
#  ['香港电影评论学会'],
#  ['骑士广场', '法国香榭大道'],
#  ['足彩', '英德'],
#  ['保监会'],
#  ['博勒沃', '拜仁'],
#  ['巴勒莫', '博洛尼'],
#  ['切沃', '乌迪内斯', '罗马', '国际米兰'],
#  ['波尔多小镇'],
#  ['阿甘疯人院'],
#  ['ac米兰', '意甲'],
#  ['浦东新区碧云', '联洋', '东城'],
#  ['国会荣誉勋章协会'],
#  ['沙尔克04', '曼城'],
#  ['杭州丁桥辰秀嘉苑12幢1单元'],
#  ['子君村'],
#  ['奥萨苏纳队', '瓦拉多利德队', '西甲'],
#  ['曼联', '布莱克本', '埃伍德公园球场'],
#  ['巴勒莫', '切沃'],
#  ['意甲', '罗马', '利沃诺'],
#  ['北京'],
#  ['沙田', '香港'],
#  ['深圳', '深圳发展银行'],
#  ['马洛卡队', '维尔瓦队', '西甲'],
#  ['工行'],
#  ['中资银行'],
#  ['乌拉圭'],
#  ['奔驰大客户部'],
#  ['加勒比海域'],
#  ['佳士得', '苏富比', '香港'],
#  ['罗马', '莱切'],
#  ['黔西南布依族苗族自治州', '贵州西南部'],
#  ['霍芬海', '比勒菲'],
#  ['长沙定王台店'],
#  ['加拉塔萨雷', '梅塔利斯特'],
#  ['立博'],
#  ['纽约'],
#  ['库塔地区', 'delibistro'],
#  ['西甲'],
#  [],
#  ['Oahu岛'],
#  ['莫斯科中央陆军', '波兹南', '拉科', '费耶诺德', '加拉塔萨雷', '梅塔利斯特'],
#  ['保险行业协会'],
#  ['英超'],
#  ['EA', '塔利班'],
#  ['英超', '伯纳乌球场'],
#  ['桑坦德'],
#  ['社区', '街道办'],
#  ['民生', '工行', '中心', '浦发', '中行', '交行', '农行', '建行'],
#  [],
#  ['联盟杯', '塞维利亚', '曼城', '乌迪内斯'],
#  ['ac米兰', '皇马'],
#  ['香港'],
#  ['公安大学'],
#  ['阿森纳'],
#  ['意甲'],
#  ['Gazillion', '好莱坞'],
#  ['奥斯卡'],
#  ['历藏公司'],
#  ['天津', '长春'],
#  ['赫尔城', '曼城'],
#  ['中央财经大学'],
#  ['尼美根', '荷甲', '莫斯科斯巴达'],
#  ['桑普多利亚', '斯图加特'],
#  ['渣打银行'],
#  ['肯尼亚边境地区'],
#  ['民生银行信用卡中心'],
#  ['苏富比', '佳士得'],
#  ['西甲', '巴萨', '潜水艇'],
#  ['上海航空'],
#  ['WCG'],
#  [],
#  ['莫斯巴', '荷兰球队'],
#  ['谷歌', 'Valve'],
#  ['广州'],
#  ['瓦拉多利德', '马略卡'],
#  ['德国达姆施塔特市'],
#  ['rbs', '荷银'],
#  ['乌迪内斯'],
#  ['ECL'],
#  ['CPL'],
#  ['江苏长江商业银行'],
#  ['长沙定王台店'],
#  ['北大西洋公约组织'],
#  ['GSL'],
#  ['俄超', '欧冠'],
#  ['俄国防部', '俄新社', '莫斯科', '列宁格勒军区', '西部战略司令部'],
#  ['福虹路', '招行'],
#  ['全明星高尔夫慈善公益赛', '湖州温泉高尔夫球场'],
#  ['阿森纳', '迪纳摩'],
#  ['中国信托业协会'],
#  ['韩亚银行', '北京金融大街17号韩亚银行营业部'],
#  ['越南'],
#  ['西汉姆联', '博尔顿'],
#  ['白宫', '五角大楼'],
#  ['“光耀东方广场”'],
#  ['博尔顿', '切尔西', '足彩'],
#  ['纽约商品交易所'],
#  ['丽泽商务区'],
#  ['交通银行（601328.sh）', '广发', '民生银行（600016.sh）'],
#  ['英超', '纽卡斯尔'],
#  ['链家地产'],
#  ['万科蓝山'],
#  ['足总杯', '纽卡'],
#  ['DICE'],
#  ['江西省宜春市保险行业协会', '邮储银行宜春分行'],
#  ['LGD'],
#  ['意甲'],
#  ['维拉', '富勒姆'],
#  ['意甲', '切沃队'],
#  ['北京'],
#  ['联赛'],
#  ['鲁能地产格拉斯小镇'],
#  ['重庆工商联'],
#  ['农行', '工', '中', '建', '交'],
#  ['埃弗顿'],
#  ['皇家贝蒂斯队'],
#  ['广东发展银行'],
#  ['育碧'],
#  ['62号大街'],
#  ['美国驻外使领馆'],
#  ['波兰', '波兹南欧', '立博'],
#  ['沙尔克', '赫塔', '足彩'],
#  ['乌克兰'],
#  ['乌迪内斯', '切沃'],
#  ['丽泽商务区'],
#  ['桂园', '八路军重庆办事处-曾家岩50号', '戴笠公馆'],
#  ['潮白河休闲旅游度假区', '北京', '燕郊'],
#  ['Games'],
#  ['西安电子科技大学'],
#  ['蒙特利尔'],
#  ['宝钢股份', '宝钢集团'],
#  ['贝尔格莱德游击队', '联盟杯'],
#  ['意甲', '桑普'],
#  ['意甲'],
#  ['桑普多', 'eurobet'],
#  ['广州市寺右新马路4号之8长城大厦3楼'],
#  ['GSL', 'OSL', 'KeSPA'],
#  ['凯恩斯'],
#  ['瓦拉多利德', '皇马', '比利亚雷亚尔', '马洛卡'],
#  ['梅塔利斯', '乌克兰联赛', '联盟杯'],
#  ['文化部', '商务部'],
#  ['阅文集团'],
#  ['零售银行'],
#  ['阿森纳'],
#  ['润泽地产', '新浪乐居', '润泽悦溪', '润泽庄园'],
#  ['蓝桥名苑'],
#  ['landmarkchater', 'chanel'],
#  ['波鸿', '赫塔', '沃尔夫', '斯图加'],
#  ['ac米兰'],
#  ['定慧寺桥'],
#  ['G联赛', '上海'],
#  ['盖蒂信托', '盖蒂博物馆'],
#  ['拜仁', '欧锦赛'],
#  ['博洛尼旗舰装饰装修工程公司'],
#  ['Disa'],
#  ['ief', '国家体育总局'],
#  ['三星', 'WCG', '杭州'],
#  ['THQ'],
#  ['红军'],
#  ['丽泽金融商务区', '金泰地产大厦'],
#  ['招行'],
#  ['米德尔斯堡', '纽卡'],
#  ['英冠', '赫尔城'],
#  ['澳彩', '那不勒斯'],
#  ['北京市海淀区双榆树西里36号南楼5层', '中国扶贫基金会紧急救援部'],
#  ['中国水电地产', '美立方'],
#  ['Valve公司'],
#  ...]

# %%
new_df = pd.DataFrame({'tag': tag_list})
new_df.to_csv('suubmit.csv', index=False)
